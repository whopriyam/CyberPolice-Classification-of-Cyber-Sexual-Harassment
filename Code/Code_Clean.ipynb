# %%
# !ls
# Out:
# Code_Clean.ipynb                    Scraping_Tweets_With_Comments.ipynb
# Models                              Tweets_Scraper.ipynb

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../Labelled_Tweets/labelled_tweets.csv")
df.head(10)
# Out:
#   Key Word         Username   User_ID          Datetime Favorite_count  Geo  \
# 0     Anal          Toybot5  1.33E+18  11-11-2020 06:42              1  NaN
# 1     Anal     _li450274625  1.33E+18  11-11-2020 06:41              1  NaN
# 2  Aroused  dmaofkansascity  1.33E+18  11-11-2020 06:44              0  NaN
# 3  Aroused      StewartEros  1.33E+18  11-11-2020 06:40              0  NaN
# 4  Aroused     zzzaaammmora  1.33E+18  11-11-2020 06:26              0  NaN
# 5  Aroused      mockalattee  1.33E+18  11-11-2020 06:23              0  NaN
# 6  Aroused       SickBamboo  1.33E+18  11-11-2020 06:20              0  NaN
# 7  Aroused      BertieMemes  1.33E+18  11-11-2020 06:15             11  NaN
# 8  Aroused  KarinaAngelique  1.33E+18  11-11-2020 05:59              0  NaN
# 9  Aroused        kryotoman  1.33E+18  11-11-2020 05:48              0  NaN
#
#   Coordinates Label                                               Text  \
# 0         NaN     1   @SwitchingSissy Without a doubt I'd choose anal.
# 1         NaN     1  @WowColorfulMart How about emperor Xi? You mus...
# 2         NaN     0  @VitalVegas You said aroused... https://t.co/p...
# 3         NaN     0  @BudgenAli If you mean to lean forward, sensua...
# 4         NaN     0  RT @obn_jay: Be wary of friends— they will bet...
# 5         NaN     0  No reason for some of y’all to be aroused twen...
# 6         NaN     0  RT @nimish4fk: I'm at a point in my life where...
# 7         NaN     0  The art style makes it difficult to decipher, ...
# 8         NaN     0  trying to understand why white women are arous...
# 9         NaN     0  I am aroused, and i havent even chosen my char...
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN         NaN         NaN
# 1        NaN         NaN         NaN
# 2        NaN         NaN         NaN
# 3        NaN         NaN         NaN
# 4        NaN         NaN         NaN
# 5        NaN         NaN         NaN
# 6        NaN         NaN         NaN
# 7        NaN         NaN         NaN
# 8        NaN         NaN         NaN
# 9        NaN         NaN         NaN

# %%
c= 0
for i in df.index:
    text = df.at[i,'Text']
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = ' '.join(x for x in text.split() if not x.startswith('RT'))
    text = ' '.join(x for x in text.split() if not x.startswith('https'))
    
    df.at[i,'Text'] = text

# %%
df.head(10)
# Out:
#   Key Word         Username   User_ID          Datetime Favorite_count  Geo  \
# 0     Anal          Toybot5  1.33E+18  11-11-2020 06:42              1  NaN
# 1     Anal     _li450274625  1.33E+18  11-11-2020 06:41              1  NaN
# 2  Aroused  dmaofkansascity  1.33E+18  11-11-2020 06:44              0  NaN
# 3  Aroused      StewartEros  1.33E+18  11-11-2020 06:40              0  NaN
# 4  Aroused     zzzaaammmora  1.33E+18  11-11-2020 06:26              0  NaN
# 5  Aroused      mockalattee  1.33E+18  11-11-2020 06:23              0  NaN
# 6  Aroused       SickBamboo  1.33E+18  11-11-2020 06:20              0  NaN
# 7  Aroused      BertieMemes  1.33E+18  11-11-2020 06:15             11  NaN
# 8  Aroused  KarinaAngelique  1.33E+18  11-11-2020 05:59              0  NaN
# 9  Aroused        kryotoman  1.33E+18  11-11-2020 05:48              0  NaN
#
#   Coordinates Label                                               Text  \
# 0         NaN     1                   Without a doubt I'd choose anal.
# 1         NaN     1  How about emperor Xi? You must enjoy licking h...
# 2         NaN     0                                You said aroused...
# 3         NaN     0  If you mean to lean forward, sensually kiss yo...
# 4         NaN     0  Be wary of friends— they will betray you more ...
# 5         NaN     0  No reason for some of y’all to be aroused twen...
# 6         NaN     0  I'm at a point in my life where I no longer ge...
# 7         NaN     0  The art style makes it difficult to decipher, ...
# 8         NaN     0  trying to understand why white women are arous...
# 9         NaN     0  I am aroused, and i havent even chosen my char...
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN         NaN         NaN
# 1        NaN         NaN         NaN
# 2        NaN         NaN         NaN
# 3        NaN         NaN         NaN
# 4        NaN         NaN         NaN
# 5        NaN         NaN         NaN
# 6        NaN         NaN         NaN
# 7        NaN         NaN         NaN
# 8        NaN         NaN         NaN
# 9        NaN         NaN         NaN

# %%
df = df.iloc[np.random.permutation(len(df))]
df.head()
# Out:
#         Key Word        Username   User_ID          Datetime Favorite_count  \
# 704          ass     DeborahParr  1.33E+18  11-11-2020 06:56              0
# 1915     boobies      MaxZorin85  1.33E+18  11-11-2020 07:35              4
# 2856   eat pussy         PRISJ1_  1.33E+18  11-11-2020 10:36              0
# 2163  Breast Man  Teresamckenzy1  1.33E+18  10-11-2020 20:52              0
# 2852   eat pussy     sj__vazquez  1.33E+18  11-11-2020 10:42              0
#
#       Geo Coordinates Label  \
# 704   NaN         NaN     1
# 1915  NaN         NaN     0
# 2856  NaN         NaN     1
# 2163  NaN         NaN     1
# 2852  NaN         NaN     1
#
#                                                    Text Unnamed: 9  \
# 704      He’d have my phone wedged up his ass sideways.        NaN
# 1915  Yep 100% agree and the same with severine in s...        NaN
# 2856  Stop having sex with men that won’t eat your p...        NaN
# 2163  When you see a sad man, just give him breast t...        NaN
# 2852        We can't be together if you don't eat pussy        NaN
#
#      Unnamed: 10 Unnamed: 11
# 704          NaN         NaN
# 1915         NaN         NaN
# 2856         NaN         NaN
# 2163         NaN         NaN
# 2852         NaN         NaN

# %%
df.to_csv("Cleaned_tweets.csv")
