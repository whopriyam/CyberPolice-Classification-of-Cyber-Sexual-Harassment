# %%
# !ls
# Out:
# Code_Clean.ipynb                    Scraping_Tweets_With_Comments.ipynb
# Models                              Tweets_Scraper.ipynb

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../Labelled_Tweets/labelled_tweets.csv")
df.head(10)
# Out:
#       Anal          Toybot5  1.33E+18  11-11-2020 06:42   1 Unnamed: 5  \
# 0     Anal     _li450274625  1.33E+18  11-11-2020 06:41   1        NaN
# 1  Aroused  dmaofkansascity  1.33E+18  11-11-2020 06:44   0        NaN
# 2  Aroused      StewartEros  1.33E+18  11-11-2020 06:40   0        NaN
# 3  Aroused     zzzaaammmora  1.33E+18  11-11-2020 06:26   0        NaN
# 4  Aroused      mockalattee  1.33E+18  11-11-2020 06:23   0        NaN
# 5  Aroused       SickBamboo  1.33E+18  11-11-2020 06:20   0        NaN
# 6  Aroused      BertieMemes  1.33E+18  11-11-2020 06:15  11        NaN
# 7  Aroused  KarinaAngelique  1.33E+18  11-11-2020 05:59   0        NaN
# 8  Aroused        kryotoman  1.33E+18  11-11-2020 05:48   0        NaN
# 9  Aroused   jordansaweirdo  1.33E+18  11-11-2020 05:38   0        NaN
#
#   Unnamed: 6 1.1   @SwitchingSissy Without a doubt I'd choose anal.  \
# 0        NaN   1  @WowColorfulMart How about emperor Xi? You mus...
# 1        NaN   0  @VitalVegas You said aroused... https://t.co/p...
# 2        NaN   0  @BudgenAli If you mean to lean forward, sensua...
# 3        NaN   0  RT @obn_jay: Be wary of friends— they will bet...
# 4        NaN   0  No reason for some of y’all to be aroused twen...
# 5        NaN   0  RT @nimish4fk: I'm at a point in my life where...
# 6        NaN   0  The art style makes it difficult to decipher, ...
# 7        NaN   0  trying to understand why white women are arous...
# 8        NaN   0  I am aroused, and i havent even chosen my char...
# 9        NaN   0  RT @VitalVegas: This rumor has aroused our int...
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN         NaN         NaN
# 1        NaN         NaN         NaN
# 2        NaN         NaN         NaN
# 3        NaN         NaN         NaN
# 4        NaN         NaN         NaN
# 5        NaN         NaN         NaN
# 6        NaN         NaN         NaN
# 7        NaN         NaN         NaN
# 8        NaN         NaN         NaN
# 9        NaN         NaN         NaN

# %%
c= 0
for i in df.index:
    text = df.at[i,'Text']
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = ' '.join(x for x in text.split() if not x.startswith('RT'))
    text = ' '.join(x for x in text.split() if not x.startswith('https'))
    
    df.at[i,'Text'] = text
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-605db5abab9a> in <module>
#       1 c= 0
#       2 for i in df.index:
# ----> 3     text = df.at[i,'Text']
#       4     text = " ".join(filter(lambda x:x[0]!='@', text.split()))
#       5     text = ' '.join(x for x in text.split() if not x.startswith('RT'))
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2151             return self.obj.loc[key]
#    2152
# -> 2153         return super().__getitem__(key)
#    2154
#    2155     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2098
#    2099         key = self._convert_key(key)
# -> 2100         return self.obj._get_value(*key, takeable=self._takeable)
#    2101
#    2102     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3127             return series._values[index]
#    3128
# -> 3129         series = self._get_item_cache(col)
#    3130         engine = self.index._engine
#    3131
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3787             #  pending resolution of GH#33047
#    3788
# -> 3789             loc = self.columns.get_loc(item)
#    3790             values = self._mgr.iget(loc)
#    3791             res = self._box_col_values(values, loc).__finalize__(self)
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Text'

# %%
df.head(10)
# Out:
#   Key Word         Username       User_ID          Datetime  Favorite_count  \
# 0  Aroused  dmaofkansascity  1.330000e+18  11-11-2020 06:44               0
# 1  Aroused      StewartEros  1.330000e+18  11-11-2020 06:40               0
# 2  Aroused     zzzaaammmora  1.330000e+18  11-11-2020 06:26               0
# 3  Aroused      mockalattee  1.330000e+18  11-11-2020 06:23               0
# 4  Aroused       SickBamboo  1.330000e+18  11-11-2020 06:20               0
# 5  Aroused      BertieMemes  1.330000e+18  11-11-2020 06:15              11
# 6  Aroused  KarinaAngelique  1.330000e+18  11-11-2020 05:59               0
# 7  Aroused        kryotoman  1.330000e+18  11-11-2020 05:48               0
# 8  Aroused   jordansaweirdo  1.330000e+18  11-11-2020 05:38               0
# 9  Aroused        AxelGrave  1.330000e+18  11-11-2020 05:37               0
#
#    Geo Coordinates  Label                                               Text
# 0  NaN         NaN      0                                You said aroused...
# 1  NaN         NaN      0  If you mean to lean forward, sensually kiss yo...
# 2  NaN         NaN      0  Be wary of friends— they will betray you more ...
# 3  NaN         NaN      0  No reason for some of y’all to be aroused twen...
# 4  NaN         NaN      0  I'm at a point in my life where I no longer ge...
# 5  NaN         NaN      0  The art style makes it difficult to decipher, ...
# 6  NaN         NaN      0  trying to understand why white women are arous...
# 7  NaN         NaN      0  I am aroused, and i havent even chosen my char...
# 8  NaN         NaN      0               This rumor has aroused our interest.
# 9  NaN         NaN      0  Another great collection of Hilarious shorts, ...

# %%
df = df.iloc[np.random.permutation(len(df))]
df.head()
# Out:
#       Key Word         Username       User_ID          Datetime  \
# 1515       ass  gametheoryosmer  1.330000e+18  11-11-2020 06:55
# 1167   bastard        oyibutter  1.330000e+18  11-11-2020 07:25
# 115   Bad Fuck     Bigafterglow  1.330000e+18  11-11-2020 07:09
# 1740     bitch     ItsBillcosby  1.330000e+18  11-11-2020 07:27
# 983        ass    SlayerOfWaifu  1.330000e+18  11-11-2020 06:55
#
#       Favorite_count  Geo Coordinates  Label  \
# 1515               0  NaN         NaN      1
# 1167               0  NaN         NaN      0
# 115                0  NaN         NaN      0
# 1740               0  NaN         NaN      1
# 983                1  NaN         NaN      0
#
#                                                    Text
# 1515  my lieutenant called me a "Pussy" for not wipi...
# 1167  My fwb showed me pepper. I caught bastard feel...
# 115                          Oh fuck! What a bad tweet.
# 1740                 If the dick fit suck it bitch 〽️™️
# 983   If you think Fairy Tail is ass you do you 🤷🏽‍♂...

# %%
df.to_csv("Cleaned_tweets.csv")
